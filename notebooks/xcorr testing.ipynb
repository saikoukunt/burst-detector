# %%
import numpy as np
import math
import burst_detector as bd
import matplotlib.pyplot as plt
import scipy
import statistics

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
times = (np.load('../data/neuropixels_dohoung/KS2.5/phy_in/spike_times.npy').flatten())/30000
clusters = np.load('../data/neuropixels_dohoung/KS2.5/phy_in/spike_clusters.npy').flatten()

# %%
test_times = bd.find_times_multi(times, clusters, [3, 6])
c1_times = test_times[0]
c2_times = test_times[1]

# %%
sig, xgram, shfl_xgram = bd.xcorr_sig(c1_times, c2_times)

# %%
print(sig)
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.bar(np.arange(100), xgram)

plt.subplot(1,2,2)
plt.bar(np.arange(100), shfl_xgram);
# Out:
# 0.7189090638950393
